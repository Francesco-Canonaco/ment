# %%
import pandas as pd

# %%
results = pd.read_csv("results.csv")

# %%
results[results['p']==100]
# Out:
#     Unnamed: 0    p    s      n  c  perturbation  run       mse    shd  \
# 40          40  100  0.2  10000  2           0.1    0  0.004462   51.5
# 41          41  100  0.2  10000  2           0.1    1  0.001833   26.5
# 42          42  100  0.2  10000  2           0.1    2  0.032100  282.0
# 43          43  100  0.2  10000  2           0.1    3  0.007186   81.0
# 44          44  100  0.2  10000  2           0.1    4  0.003623   45.0
# 45          45  100  0.2  10000  2           0.1    5  0.006169   65.5
# 46          46  100  0.2  10000  2           0.1    6  0.007229   78.5
# 47          47  100  0.2  10000  2           0.1    7  0.011100  121.5
# 48          48  100  0.2  10000  2           0.1    8  0.013527  132.0
# 49          49  100  0.2  10000  2           0.1    9  0.007174   78.0
# 50          50  100  0.2  30000  2           0.1    0  0.007294   71.5
# 51          51  100  0.2  30000  2           0.1    1  0.008601   81.0
# 52          52  100  0.2  30000  2           0.1    2  0.001727   24.0
# 53          53  100  0.2  30000  2           0.1    3  0.015956  152.0
# 54          54  100  0.2  30000  2           0.1    4  0.002506   29.5
# 55          55  100  0.2  30000  2           0.1    5  0.006553   71.0
# 56          56  100  0.2  30000  2           0.1    6  0.008182   78.0
# 57          57  100  0.2  30000  2           0.1    7  0.000551    9.5
# 58          58  100  0.2  30000  2           0.1    8  0.010318   99.5
# 59          59  100  0.2  30000  2           0.1    9  0.006193   67.5
# 60          60  100  0.3  10000  2           0.1    0  0.061999  559.0
# 61          61  100  0.3  10000  2           0.1    1  0.067711  608.0
# 62          62  100  0.3  10000  2           0.1    2  0.062529  578.0
# 63          63  100  0.3  10000  2           0.1    3  0.044081  398.5
# 64          64  100  0.3  10000  2           0.1    4  0.062033  551.0
# 65          65  100  0.3  10000  2           0.1    5  0.057018  495.5
# 66          66  100  0.3  10000  2           0.1    6  0.077896  678.0
# 67          67  100  0.3  10000  2           0.1    7  0.057650  506.0
# 68          68  100  0.3  10000  2           0.1    8  0.068794  595.5
# 69          69  100  0.3  10000  2           0.1    9  0.067914  607.5
# 70          70  100  0.3  30000  2           0.1    0  0.056715  486.0
# 71          71  100  0.3  30000  2           0.1    1  0.052982  474.5
# 72          72  100  0.3  30000  2           0.1    2  0.067255  587.5
# 73          73  100  0.3  30000  2           0.1    3  0.059350  513.5
# 74          74  100  0.3  30000  2           0.1    4  0.078456  679.5
# 75          75  100  0.3  30000  2           0.1    5  0.059818  510.0
# 76          76  100  0.3  30000  2           0.1    6  0.067453  578.5
# 77          77  100  0.3  30000  2           0.1    7  0.053877  449.5
# 78          78  100  0.3  30000  2           0.1    8  0.071735  607.0
# 79          79  100  0.3  30000  2           0.1    9  0.067313  599.0
#
#     precision    recall
# 40   0.988684  0.961649
# 41   0.990133  0.983680
# 42   0.993989  0.728739
# 43   0.988841  0.929641
# 44   0.991314  0.963718
# 45   0.994902  0.934899
# 46   0.989494  0.927292
# 47   0.991808  0.880977
# 48   0.993011  0.870370
# 49   0.989685  0.933202
# 50   0.995420  0.930124
# 51   0.996918  0.924345
# 52   0.994794  0.980573
# 53   0.998883  0.851232
# 54   0.996804  0.972425
# 55   0.994978  0.931017
# 56   0.998951  0.923687
# 57   0.998435  0.991710
# 58   0.997176  0.901020
# 59   0.997781  0.932124
# 60   0.996083  0.616102
# 61   0.994209  0.602243
# 62   0.992856  0.614189
# 63   0.998618  0.722572
# 64   0.997988  0.637624
# 65   0.995376  0.663699
# 66   0.997067  0.558785
# 67   0.994480  0.682338
# 68   0.996743  0.610197
# 69   0.997712  0.593897
# 70   0.998537  0.674176
# 71   0.999485  0.676230
# 72   0.999467  0.612797
# 73   0.999486  0.664706
# 74   0.999359  0.537781
# 75   0.998959  0.656081
# 76   0.999483  0.619737
# 77   0.998989  0.694482
# 78   1.000000  0.596410
# 79   0.999455  0.590629

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
A = np.random.randint(0, 10, size=(10, 10))
B = np.random.randint(0, 10, size=(10, 10))

# %%
mean_squared_error(A.flatten(), B.flatten())
# Out:
# 12.86

# %%
A
# Out:
# array([[5, 0, 3, 9, 8, 5, 7, 4, 4, 1],
#        [7, 8, 4, 7, 3, 2, 9, 3, 2, 6],
#        [3, 5, 8, 2, 0, 5, 5, 0, 6, 1],
#        [1, 0, 8, 3, 9, 0, 7, 2, 0, 4],
#        [5, 6, 7, 7, 4, 2, 4, 7, 3, 4],
#        [8, 8, 1, 5, 2, 4, 4, 9, 9, 5],
#        [1, 5, 7, 3, 7, 3, 7, 6, 4, 7],
#        [4, 1, 9, 1, 2, 7, 1, 0, 5, 8],
#        [7, 2, 6, 0, 2, 8, 5, 5, 1, 6],
#        [6, 5, 2, 5, 8, 7, 8, 7, 7, 5]])

# %%
B
# Out:
# array([[4, 8, 7, 1, 5, 9, 9, 2, 3, 8],
#        [0, 5, 7, 8, 2, 6, 7, 2, 4, 3],
#        [7, 2, 5, 8, 2, 5, 6, 6, 4, 8],
#        [0, 0, 6, 5, 4, 6, 2, 3, 4, 9],
#        [3, 9, 5, 1, 5, 3, 0, 0, 2, 1],
#        [2, 2, 7, 1, 6, 3, 6, 7, 4, 2],
#        [4, 1, 9, 2, 6, 8, 7, 8, 5, 6],
#        [5, 8, 0, 0, 3, 5, 3, 1, 3, 8],
#        [3, 3, 3, 0, 0, 5, 8, 6, 4, 3],
#        [7, 7, 1, 3, 5, 4, 8, 1, 8, 4]])

# %%
a_flatten = A.flatten()

# %%
b_flatten = B.flatten()

# %%
errors_sum = 0
for i in range(0, 100):
    errors_sum  += (a_flatten[i]-b_flatten[i])**2
print(errors_sum / 100)
# Out:
# 12.86

# %%
2**4
# Out:
# 16
